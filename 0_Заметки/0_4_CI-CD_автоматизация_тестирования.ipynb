# %% [markdown]
# # Введение в CI/CD - автоматизация тестирования

# %% [markdown]
# CI/CD (Continuous Integration/Continuous Delivery/Deployment) - это подход к разработке, который позволяет автоматизировать процессы сборки, тестирования и развертывания приложений.
#
# **Continuous Integration (CI)** - автоматическая сборка и тестирование кода при каждом изменении. Цель: быстро выявлять конфликты и ошибки.
# **Continuous Delivery/Deployment (CD)** - автоматическое развертывание приложения на тестовые или продакшен-среды после успешного прохождения тестов.

# %% [markdown]
# Зачем автоматизировать тестирование в CI/CD?
# - Ускорение разработки: тесты запускаются автоматически при каждом коммите.
# - Раннее обнаружение ошибок: проблемы выявляются до попадания в продакшен.
# - Повышение качества кода: гарантия, что изменения не ломают существующую функциональность.

# %% [markdown]
# Виды тестов в CI/CD
# | Тип тестирования | Описание | Пример инструментов |
# |----------|----------|----------|
# | Юнит-тесты | 	Проверка отдельных модулей кода. | pytest, unittest |
# | Интеграционные тесты   | Проверка взаимодействия между компонентами. | Postman, requests |
# | Системные тесты | Тестирование приложения в целом (эндпоинты, UI). | Selenium, Cypress |
# | Регрессионные тесты | Проверка, что новые изменения не сломали существующую функциональность. | Интеграция с фреймворками |

# %% [markdown]
# Инструменты для CI/CD
# **GitHub Actions** - встроенный инструмент GitHub для настройки пайплайнов.
# **GitLab CI/CD** - аналогичный инструмент в GitLab (пример конфигурации .gitlab-ci.yml).
# **Jenkins** - гибкий CI/CD-сервер с поддержкой плагинов (опыт использования).
# **Test IT CLI** - утилита для загрузки результатов тестов в системы управления тестированием.

# %% [markdown]
# # Основы работы с Docker для контейнеризации приложений
